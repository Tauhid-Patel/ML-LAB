# %% [markdown]
# # All Concepts:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#display dataframe
df = pd.read_csv('/content/drive/MyDrive/AI_Datasets/Heart.csv')
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# ...

# %%
#Disp last col of dataframe
last_col=df.iloc[:,-1]

# %%
#Missing values 
df.isnull().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         2
# AHD          0
# dtype: int64

# %%
# If missing, replace the.
df.Thal.value_counts()
# Out:
# normal        166
# reversable    117
# fixed          18
# Name: Thal, dtype: int64

# %%
#Since 'normal' is occuring fequently, we replace null value of thal with 'normal'.
df.Thal=df.Thal.fillna(df.Thal.value_counts().index[0])

# %%
#here we can see the increase in count of 'normal'
df.Thal.value_counts()
# Out:
# normal        168
# reversable    117
# fixed          18
# Name: Thal, dtype: int64

# %%
df.isnull().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         0
# AHD          0
# dtype: int64

# %%
#Replacing Ca with 0.0 as it has the max occurance.
df.Ca.value_counts()
# Out:
# 0.0    176
# 1.0     65
# 2.0     38
# 3.0     20
# Name: Ca, dtype: int64

# %%
df.Ca=df.Ca.fillna(df.Ca.value_counts().index[0])
df.Ca.value_counts()
# Out:
# 0.0    180
# 1.0     65
# 2.0     38
# 3.0     20
# Name: Ca, dtype: int64

# %%
#correlation
df.corr()
# Out:
#               Age       Sex    RestBP      Chol       Fbs   RestECG     MaxHR  \
# Age      1.000000 -0.097542  0.284946  0.208950  0.118530  0.148868 -0.393806
# Sex     -0.097542  1.000000 -0.064456 -0.199915  0.047862  0.021647 -0.048663
# RestBP   0.284946 -0.064456  1.000000  0.130120  0.175340  0.146560 -0.045351
# Chol     0.208950 -0.199915  0.130120  1.000000  0.009841  0.171043 -0.003432
# Fbs      0.118530  0.047862  0.175340  0.009841  1.000000  0.069564 -0.007854
# RestECG  0.148868  0.021647  0.146560  0.171043  0.069564  1.000000 -0.083389
# MaxHR   -0.393806 -0.048663 -0.045351 -0.003432 -0.007854 -0.083389  1.000000
# ExAng    0.091661  0.146201  0.064762  0.061310  0.025665  0.084867 -0.378103
# Oldpeak  0.203805  0.102173  0.189171  0.046564  0.005747  0.114133 -0.343085
# Slope    0.161770  0.037533  0.117382 -0.004062  0.059894  0.133946 -0.385601
# Ca       0.365323  0.086048  0.097528  0.123726  0.140764  0.131749 -0.265699
#
# ...

# %%
#heatmap
hmp = sns.heatmap(df.corr(), annot=True)
hmp

# %%
#disp last 5 records
df.tail(5)
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 298      1.2      2  0.0  reversable  Yes
# 299      3.4      2  2.0  reversable  Yes
# 300      1.2      2  1.0  reversable  Yes
# 301      0.0      2  1.0      normal  Yes
# 302      0.0      1  0.0      normal   No

# %%
#first 5 recs
df.head(5)
# Out:
#    Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0   63    1       typical     145   233    1        2    150      0      2.3
# 1   67    1  asymptomatic     160   286    0        2    108      1      1.5
# 2   67    1  asymptomatic     120   229    0        2    129      1      2.6
# 3   37    1    nonanginal     130   250    0        0    187      0      3.5
# 4   41    0    nontypical     130   204    0        2    172      0      1.4
#
#    Slope   Ca        Thal  AHD
# 0      3  0.0       fixed   No
# 1      2  3.0      normal  Yes
# 2      2  2.0  reversable  Yes
# 3      3  0.0      normal   No
# 4      1  0.0      normal   No

# %%
#random 5 recs
df.sample(5)
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 127   54    1  asymptomatic     110   239    0        0    126      1
# 46    51    1    nonanginal     110   175    0        0    123      0
# 3     37    1    nonanginal     130   250    0        0    187      0
# 48    65    0    nonanginal     140   417    1        2    157      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 300      1.2      2  1.0  reversable  Yes
# 127      2.8      2  1.0  reversable  Yes
# 46       0.6      1  0.0      normal   No
# 3        3.5      3  0.0      normal   No
# 48       0.8      1  1.0      normal   No

# %%
#Scatterplot
sns.scatterplot(df.MaxHR, df.Chol)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Genderwise count of entries
df.Sex.value_counts()
# Out:
# 1    206
# 0     97
# Name: Sex, dtype: int64

# %%
#unique values in ChestPain column
df.ChestPain.unique()
# Out:
# array(['typical', 'asymptomatic', 'nonanginal', 'nontypical'],
#       dtype=object)

# %%
#Mean value for Age column
df.Age.mean()
# Out:
# 54.43894389438944

# %%
#diagnosis count of each type
df.AHD.value_counts()
# Out:
# No     164
# Yes    139
# Name: AHD, dtype: int64

# %%
#Display box plot of gender and age
sns.boxplot(df.Sex, df.Age)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#sex wise ahd wise count of entries
df.groupby(['Sex', 'AHD']).AHD.count()
# Out:
# Sex  AHD
# 0    No      72
#      Yes     25
# 1    No      92
#      Yes    114
# Name: AHD, dtype: int64

# %%
#crosstab
pd.crosstab(df.Sex, df.AHD)
# Out:
# AHD  No  Yes
# Sex
# 0    72   25
# 1    92  114

# %%
#disp countplot
sns.countplot(df.Thal)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.Thal.unique()
# Out:
# array(['fixed', 'normal', 'reversable'], dtype=object)

# %%
#display columns
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs', 'RestECG', 'MaxHR',
#        'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'AHD'],
#       dtype='object')

# %%
#display any 2 columns
df[['ChestPain', 'Thal']]
# Out:
#         ChestPain        Thal
# 0         typical       fixed
# 1    asymptomatic      normal
# 2    asymptomatic  reversable
# 3      nonanginal      normal
# 4      nontypical      normal
# ..            ...         ...
# 298       typical  reversable
# 299  asymptomatic  reversable
# 300  asymptomatic  reversable
# 301    nontypical      normal
# 302    nonanginal      normal
#
# [303 rows x 2 columns]

# %%
#describe the dataset
df.describe()
# Out:
#               Age         Sex      RestBP        Chol         Fbs     RestECG  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868  131.689769  246.693069    0.148515    0.990099
# std      9.038662    0.467299   17.599748   51.776918    0.356198    0.994971
# min     29.000000    0.000000   94.000000  126.000000    0.000000    0.000000
# 25%     48.000000    0.000000  120.000000  211.000000    0.000000    0.000000
# 50%     56.000000    1.000000  130.000000  241.000000    0.000000    1.000000
# 75%     61.000000    1.000000  140.000000  275.000000    0.000000    2.000000
# max     77.000000    1.000000  200.000000  564.000000    1.000000    2.000000
#
#             MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   149.607261    0.326733    1.039604    1.600660    0.663366
# std     22.875003    0.469794    1.161075    0.616226    0.934375
# ...

# %%
df[['ChestPain', 'Sex','Age','RestBP']]
# Out:
#         ChestPain  Sex  Age  RestBP
# 0         typical    1   63     145
# 1    asymptomatic    1   67     160
# 2    asymptomatic    1   67     120
# 3      nonanginal    1   37     130
# 4      nontypical    0   41     130
# ..            ...  ...  ...     ...
# 298       typical    1   45     110
# 299  asymptomatic    1   68     144
# 300  asymptomatic    1   57     130
# 301    nontypical    0   57     130
# 302    nonanginal    1   38     138
#
# [303 rows x 4 columns]

# %%
#display information of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        303 non-null    int64
#  1   Sex        303 non-null    int64
#  2   ChestPain  303 non-null    object
#  3   RestBP     303 non-null    int64
#  4   Chol       303 non-null    int64
#  5   Fbs        303 non-null    int64
#  6   RestECG    303 non-null    int64
#  7   MaxHR      303 non-null    int64
#  8   ExAng      303 non-null    int64
#  9   Oldpeak    303 non-null    float64
#  10  Slope      303 non-null    int64
#  11  Ca         303 non-null    float64
#  12  Thal       303 non-null    object
#  13  AHD        303 non-null    object
# dtypes: float64(2), int64(9), object(3)
# memory usage: 33.3+ KB

# %%
#Normal Encoding Technique
df_encoding = pd.get_dummies(df[['ChestPain', 'AHD','Thal' ]])
df_encoding
# Out:
#      ChestPain_asymptomatic  ChestPain_nonanginal  ChestPain_nontypical  \
# 0                         0                     0                     0
# 1                         1                     0                     0
# 2                         1                     0                     0
# 3                         0                     1                     0
# 4                         0                     0                     1
# ..                      ...                   ...                   ...
# 298                       0                     0                     0
# 299                       1                     0                     0
# 300                       1                     0                     0
# 301                       0                     0                     1
# 302                       0                     1                     0
#
#      ChestPain_typical  AHD_No  AHD_Yes  Thal_fixed  Thal_normal  \
# ...

# %%
df_encoding.columns
# Out:
# Index(['ChestPain_asymptomatic', 'ChestPain_nonanginal',
#        'ChestPain_nontypical', 'ChestPain_typical', 'AHD_No', 'AHD_Yes',
#        'Thal_fixed', 'Thal_normal', 'Thal_reversable'],
#       dtype='object')

# %%
#categorical plot --> catplot
sns.catplot(x='MaxHR', y='Chol', data=df)

# %%
df[(df['Age'] > 18) & (df['Age'] <45)]
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# 13    44    1    nontypical     120   263    0        0    173      0
# 28    43    1  asymptomatic     150   247    0        0    171      0
# 29    40    1  asymptomatic     110   167    0        2    114      1
# 34    44    1    nonanginal     130   233    0        0    179      1
# 35    42    1  asymptomatic     140   226    0        0    178      0
# 36    43    1  asymptomatic     120   177    0        2    120      1
# 41    40    1       typical     140   199    0        0    178      1
# 50    41    0    nontypical     105   198    0        0    168      0
# 52    44    1  asymptomatic     112   290    0        2    153      0
# 53    44    1    nontypical     130   219    0        2    188      0
# ...

# %%
#Histogram
sns.histplot('ChestPain')

# %%
sns.distplot(df.Chol)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # MinMaxScaler Preprocessing

# %%
from sklearn preprocessing import MinMax
