# %% [markdown]
# ##Rollno: 1233
#
# ##Name: Kirti Vichare

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb

# %%
df= pd.read_csv("Salary_Data.csv")
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
df.isnull()
# Out:
#     YearsExperience  Salary
# 0             False   False
# 1             False   False
# 2             False   False
# 3             False   False
# 4             False   False
# 5             False   False
# 6             False   False
# 7             False   False
# 8             False   False
# 9             False   False
# 10            False   False
# 11            False   False
# 12            False   False
# 13            False   False
# 14            False   False
# 15            False   False
# 16            False   False
# 17            False   False
# 18            False   False
# 19            False   False
# 20            False   False
# 21            False   False
# 22            False   False
# 23            False   False
# 24            False   False
# 25            False   False
# 26            False   False
# 27            False   False
# 28            False   False
# 29            False   False

# %%
#check for null values
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,1].values

# %%
plt.plot(x,y)
plt.title("Years of Experience vs Salary")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(x,y)
plt.title("Years of Experience vs Salary")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=1)

# %%
x_train
# Out:
# array([[ 8.7],
#        [ 7.9],
#        [ 8.2],
#        [ 2.2],
#        [ 1.5],
#        [ 9. ],
#        [ 3. ],
#        [ 5.9],
#        [ 4.1],
#        [ 3.2],
#        [ 9.6],
#        [ 1.3],
#        [ 5.1],
#        [ 1.1],
#        [ 4.9],
#        [10.5],
#        [10.3],
#        [ 3.7],
#        [ 3.2],
#        [ 4. ],
#        [ 4. ],
#        [ 2.9]])

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
y_train_pred = regressor.predict(x_train)

# %%
plt.scatter(x_train,y_train,color="green")
plt.plot(x_train,y_train_pred,color="red")
plt.title("Years of Experience vs Salary(Training Dataset)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(x_test,y_test,color="blue")
plt.plot(x_test,y_pred,color="red")
plt.title("Years of Experience vs Salary(Training Dataset)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# **Evaluation**

# %%
from sklearn.metrics import r2_score
import numpy as np

# %%
print("Mean absolute error: %.2f" % np.mean(np.absolute(y_pred - y_test)))
print("Mean Squared error: %.2f" % np.mean((y_pred - y_test)**2))
print("Root Mean Squared error: %.2f" % np.sqrt(np.mean(y_pred - y_test)**2))
print("r2_score: %.2f" %r2_score(y_pred,y_test))
# Out:
# Mean absolute error: 5215.55
# Mean Squared error: 40884620.50
# Root Mean Squared error: 3378.35
# r2_score: 0.89

# %%
print("Training Data")
print("Mean absolute error: %.2f" % np.mean(np.absolute(y_train_pred - y_train)))
print("Mean Squared error: %.2f" % np.mean((y_train_pred - y_train)**2))
print("Root Mean Squared error: %.2f" % np.sqrt(np.mean(y_train_pred - y_train)**2))
print("r2_score: %.2f" %r2_score(y_train_pred,y_train))
# Out:
# Training Data
# Mean absolute error: 4538.96
# Mean Squared error: 29258602.85
# Root Mean Squared error: 0.00
# r2_score: 0.96

# %%
plt.scatter(x_test,y_test,color="blue")
plt.plot(x_test,y_pred,color="orange")
plt.title("Years of Experience vs Salary(Training Dataset)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ##**Lasso Regression**

# %%
#model training
from sklearn.linear_model import Lasso
modelL = Lasso(alpha=0.1)
modelL.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
y_pred = modelL.predict(x_test)
print(modelL.coef_)
print(modelL.intercept_)
# Out:
# [9261.55724052]
# 25892.36397311779

# %% [markdown]
# **y = 9261.55724052x + 25892.36397311779**

# %%
from sklearn import metrics

print("MAE:",metrics.mean_absolute_error(y_test,y_pred))
print("MSE",metrics.mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# MAE: 5215.569585855568
# MSE 40884752.774098106
# RMSE 6394.11860807243

# %% [markdown]
# ##Ridge Regression

# %%
from sklearn.linear_model import Ridge
modelR=Ridge(alpha=1)
modelR.fit(x_train,y_train)
# Out:
# Ridge()

# %%
y_pred = modelR.predict(x_test)
print(modelR.coef_)
print(modelR.intercept_)
# Out:
# [9214.605369]
# 26136.300287419224

# %%
from sklearn.linear_model import ElasticNet
modelE=ElasticNet(random_state=0)
modelE.fit(x_train,y_train)
# Out:
# ElasticNet(random_state=0)

# %%
y_pred = modelE.predict(x_test)
print(modelE.coef_)
print(modelE.intercept_)
# Out:
# [8769.85243309]
# 28446.99394991016
